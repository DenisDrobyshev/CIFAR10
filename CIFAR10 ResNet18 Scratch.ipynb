# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.backends.cudnn as cudnn
import torch.optim as optim
import os
import torchvision
import torchvision.transforms as transforms

# %%
class BasicBlock(nn.Module):
    def __init__(self, in_planes, planes, stride = 1):
        super(BasicBlock, self).__init__()

        self.conv1 = nn.Conv2d(in_planes, planes, kernel_size = 3, stride = stride, padding = 1, bias = False)
        self.bn1 = nn.BatchNorm2d(planes)

        self.conv2 = nn.Conv2d(planes,planes,kernel_size = 3, stride = 1, padding = 1, bias = False)
        self.bn2 = nn.BatchNorm2d(planes)

        self.shortcut = nn.Identity()
        if stride != 1:
            self.shortcut = nn.Sequential(
                            nn.Conv2d(in_planes, planes, kernel_size = 1, stride = stride, bias = False),
                            nn.BatchNorm2d(planes)
                            )

    def forward(self, x):
        out = F.relu(self.bn1(self.conv1(x)))
        out = self.bn2(self.conv2(out))
        out += self.shortcut(x)
        out = F.relu(out)

        return out

# %%
class ResNet(nn.Module):
    def __init__(self, block, num_blocks, num_classes = 10):
        super(ResNet, self).__init__()
        self.in_planes = 64

        self.conv1 = nn.Conv2d(3,64,kernel_size = 3, stride = 1, padding = 1, bias = False)
        self.bn1 = nn.BatchNorm2d(64)
        self.layer1 = self._make_layer(block, 64, num_blocks[0], stride = 1)
        self.layer2 = self._make_layer(block, 128, num_blocks[1], stride = 2)
        self.layer3 = self._make_layer(block, 256, num_blocks[2], stride = 2)
        self.layer4 = self._make_layer(block, 512, num_blocks[3], stride = 2)
        self.linear = nn.Linear(512, num_classes)

    def _make_layer(self, block, planes, num_blocks, stride):
        strides = [stride] + [1] * (num_blocks - 1)
        layers = []

        for stride in strides:
            layers.append(block(self.in_planes, planes, stride))
            self.in_planes = planes

        return nn.Sequential(*layers)

    def forward(self, x):
        out = F.relu(self.bn1(self.conv1(x)))
        out = self.layer1(out)
        out = self.layer2(out)
        out = self.layer3(out)
        out = self.layer4(out)
        out = F.avg_pool2d(out, 4)
        out = out.view(out.size(0), -1) # out.size(0) = out.reshape(0)
        out = self.linear(out)

        return out

# %%
train = transforms.Compose([
    transforms.RandomCrop(32, padding = 4),
    transforms.RandomHorizontalFlip(),
    transforms.ToTensor(),
])

test = transforms.Compose([
    transforms.ToTensor(),
])

train_dataset = torchvision.datasets.CIFAR10(root= './data', train = True, download = True, transform = train)
test_dataset = torchvision.datasets.CIFAR10(root= './data', train = False, download = True, transform = test)

train_loader = torch.utils.data.DataLoader(train_dataset, batch_size = 128, shuffle = True, num_workers = 4)
test_loader = torch.utils.data.DataLoader(test_dataset, batch_size = 100, shuffle = False, num_workers = 4)
# Out:
# Files already downloaded and verified
# Files already downloaded and verified

# %%
def ResNet18():
    return ResNet(BasicBlock, [2,2,2,2])

# %%
device = 'cuda'
cudnn.benchmark = True

net = ResNet18()
net = net.to(device)
net = torch.nn.DataParallel(net)

learning_rate = 0.1
file_name = 'resnet18_cifar10.pth'

criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(net.parameters(), lr = learning_rate, momentum = 0.9, weight_decay = 0.0002)

# %%
def train(epoch):
    print('\n[ Train epoch: %d ]' % epoch)
    net.train()
    train_loss = 0
    correct = 0
    total = 0

    for batch_idx, (inputs, targets) in  enumerate(train_loader):
        inputs= inputs.to(device)
        targets = targets.to(device)

        outputs = net(inputs)

        optimizer.zero_grad()
        loss = criterion(outputs, targets)
        loss.backward()
        optimizer.step()

        train_loss += loss.item()
        _, predicted = outputs.max(1)

        total += targets.size(0)
        correct += predicted.eq(targets).sum().item()

        if batch_idx % 100 == 0:
            print('\nCurrent batch:', str(batch_idx))
            print('Current benign train accuracy:', str(predicted.eq(targets).sum().item() / targets.size(0)))
            print('Current benign train loss:', loss.item())

    print('\nTotal benign train accuarcy:', 100. * correct / total)
    print('Total benign train loss:', train_loss)

# %%
def test(epoch):
    print('\n[ Test epoch: %d ]' % epoch)
    net.eval()
    loss = 0
    correct = 0
    total = 0

    for batch_idx, (inputs, targets) in enumerate(test_loader):
        inputs, targets = inputs.to(device), targets.to(device)
        total += targets.size(0)

        outputs = net(inputs)
        loss += criterion(outputs, targets).item()

        _, predicted = outputs.max(1)
        correct += predicted.eq(targets).sum().item()

    print('\nTest accuarcy:', 100. * correct / total)
    print('Test average loss:', loss / total)

    state = {
        'net': net.state_dict()
    }
    if not os.path.isdir('checkpoint'):
        os.mkdir('checkpoint')
    torch.save(state, './checkpoint/' + file_name)
    print('Model Saved!')

# %%
def adjust_learning_rate(optimizer, epoch):
    lr = learning_rate
    if epoch >= 100:
        lr /= 10
    if epoch >= 150:
        lr /= 10
    for param_group in optimizer.param_groups:
        param_group['lr'] = lr

# %%
for epoch in range(0, 20):
    adjust_learning_rate(optimizer, epoch)
    train(epoch)
    test(epoch)
# Out:
# [ Train epoch: 0 ]
#
# Current batch: 0
# Current benign train accuracy: 0.1015625
# Current benign train loss: 2.3281350135803223
#
# Current batch: 100
# Current benign train accuracy: 0.3515625
# Current benign train loss: 1.8828078508377075
#
# Current batch: 200
# Current benign train accuracy: 0.296875
# Current benign train loss: 1.8152875900268555
#
# Current batch: 300
# Current benign train accuracy: 0.359375
# Current benign train loss: 1.7569916248321533
#
# Total benign train accuarcy: 30.184
# Total benign train loss: 761.4594428539276
#
# [ Test epoch: 0 ]
#
# Test accuarcy: 39.0
# Test average loss: 0.016725183475017547
# Model Saved!
#
# [ Train epoch: 1 ]
#
# Current batch: 0
# Current benign train accuracy: 0.4140625
# Current benign train loss: 1.5157055854797363
#
# Current batch: 100
# Current benign train accuracy: 0.4140625
# Current benign train loss: 1.5088170766830444
#
# Current batch: 200
# Current benign train accuracy: 0.453125
# Current benign train loss: 1.5140979290008545
#
# Current batch: 300
# Current benign train accuracy: 0.5234375
# Current benign train loss: 1.3927791118621826
#
# Total benign train accuarcy: 44.908
# Total benign train loss: 580.9911903142929
#
# [ Test epoch: 1 ]
#
# Test accuarcy: 50.25
# Test average loss: 0.014445337021350861
# Model Saved!
#
# [ Train epoch: 2 ]
#
# Current batch: 0
# Current benign train accuracy: 0.4921875
# Current benign train loss: 1.4333957433700562
#
# Current batch: 100
# Current benign train accuracy: 0.5703125
# Current benign train loss: 1.2670711278915405
#
# Current batch: 200
# Current benign train accuracy: 0.578125
# Current benign train loss: 1.1669410467147827
#
# Current batch: 300
# Current benign train accuracy: 0.546875
# Current benign train loss: 1.0711573362350464
#
# Total benign train accuarcy: 54.9
# Total benign train loss: 487.77271980047226
#
# [ Test epoch: 2 ]
#
# Test accuarcy: 53.3
# Test average loss: 0.012863812506198884
# Model Saved!
#
# [ Train epoch: 3 ]
#
# Current batch: 0
# Current benign train accuracy: 0.6015625
# Current benign train loss: 1.1167967319488525
#
# Current batch: 100
# Current benign train accuracy: 0.625
# Current benign train loss: 1.062306523323059
#
# Current batch: 200
# Current benign train accuracy: 0.640625
# Current benign train loss: 1.1029938459396362
#
# Current batch: 300
# Current benign train accuracy: 0.6796875
# Current benign train loss: 0.9832319021224976
#
# Total benign train accuarcy: 62.29
# Total benign train loss: 412.89097994565964
#
# [ Test epoch: 3 ]
#
# Test accuarcy: 62.59
# Test average loss: 0.010702464842796326
# Model Saved!
#
# [ Train epoch: 4 ]
#
# Current batch: 0
# Current benign train accuracy: 0.6484375
# Current benign train loss: 1.0280240774154663
#
# Current batch: 100
# Current benign train accuracy: 0.671875
# Current benign train loss: 0.9347017407417297
#
# Current batch: 200
# Current benign train accuracy: 0.703125
# Current benign train loss: 0.8655410408973694
#
# Current batch: 300
# Current benign train accuracy: 0.671875
# Current benign train loss: 0.865482747554779
#
# Total benign train accuarcy: 67.532
# Total benign train loss: 358.0148352384567
#
# [ Test epoch: 4 ]
#
# Test accuarcy: 64.89
# Test average loss: 0.009891448450088502
# Model Saved!
#
# [ Train epoch: 5 ]
#
# Current batch: 0
# Current benign train accuracy: 0.734375
# Current benign train loss: 0.7707269787788391
#
# Current batch: 100
# Current benign train accuracy: 0.6875
# Current benign train loss: 0.932874321937561
#
# Current batch: 200
# Current benign train accuracy: 0.7109375
# Current benign train loss: 0.8085489869117737
#
# Current batch: 300
# Current benign train accuracy: 0.765625
# Current benign train loss: 0.7049357295036316
#
# Total benign train accuarcy: 71.098
# Total benign train loss: 318.88990527391434
#
# [ Test epoch: 5 ]
#
# Test accuarcy: 72.7
# Test average loss: 0.007864806169271469
# Model Saved!
#
# [ Train epoch: 6 ]
#
# Current batch: 0
# Current benign train accuracy: 0.7265625
# Current benign train loss: 0.6708446741104126
#
# Current batch: 100
# Current benign train accuracy: 0.765625
# Current benign train loss: 0.7532932162284851
#
# Current batch: 200
# Current benign train accuracy: 0.796875
# Current benign train loss: 0.6366395950317383
#
# Current batch: 300
# Current benign train accuracy: 0.78125
# Current benign train loss: 0.5975607633590698
#
# Total benign train accuarcy: 74.092
# Total benign train loss: 287.8730585575104
#
# [ Test epoch: 6 ]
#
# Test accuarcy: 66.98
# Test average loss: 0.009422393745183945
# Model Saved!
#
# [ Train epoch: 7 ]
#
# Current batch: 0
# Current benign train accuracy: 0.7578125
# Current benign train loss: 0.6253232955932617
#
# Current batch: 100
# Current benign train accuracy: 0.7265625
# Current benign train loss: 0.7647103667259216
#
# Current batch: 200
# Current benign train accuracy: 0.7421875
# Current benign train loss: 0.6783198118209839
#
# Current batch: 300
# Current benign train accuracy: 0.8125
# Current benign train loss: 0.5502058267593384
#
# Total benign train accuarcy: 76.292
# Total benign train loss: 261.15546560287476
#
# [ Test epoch: 7 ]
#
# Test accuarcy: 73.85
# Test average loss: 0.007536991417407989
# Model Saved!
#
# [ Train epoch: 8 ]
#
# Current batch: 0
# Current benign train accuracy: 0.765625
# Current benign train loss: 0.5688343048095703
#
# Current batch: 100
# Current benign train accuracy: 0.7265625
# Current benign train loss: 0.6707125902175903
#
# Current batch: 200
# Current benign train accuracy: 0.8046875
# Current benign train loss: 0.553403913974762
#
# Current batch: 300
# Current benign train accuracy: 0.7734375
# Current benign train loss: 0.6055744886398315
#
# Total benign train accuarcy: 78.972
# Total benign train loss: 235.5826113820076
#
# [ Test epoch: 8 ]
#
# Test accuarcy: 69.45
# Test average loss: 0.008969358295202255
# Model Saved!
#
# [ Train epoch: 9 ]
#
# Current batch: 0
# Current benign train accuracy: 0.8046875
# Current benign train loss: 0.5364542007446289
#
# Current batch: 100
# Current benign train accuracy: 0.7890625
# Current benign train loss: 0.6086902618408203
#
# Current batch: 200
# Current benign train accuracy: 0.796875
# Current benign train loss: 0.48019957542419434
#
# Current batch: 300
# Current benign train accuracy: 0.84375
# Current benign train loss: 0.43794336915016174
#
# Total benign train accuarcy: 80.864
# Total benign train loss: 214.30046850442886
#
# [ Test epoch: 9 ]
#
# Test accuarcy: 79.69
# Test average loss: 0.006010120832920075
# Model Saved!
#
# [ Train epoch: 10 ]
#
# Current batch: 0
# Current benign train accuracy: 0.8203125
# Current benign train loss: 0.49834030866622925
#
# Current batch: 100
# Current benign train accuracy: 0.8359375
# Current benign train loss: 0.4855194687843323
#
# Current batch: 200
# Current benign train accuracy: 0.828125
# Current benign train loss: 0.4586162865161896
#
# Current batch: 300
# Current benign train accuracy: 0.8203125
# Current benign train loss: 0.49708807468414307
#
# Total benign train accuarcy: 82.714
# Total benign train loss: 194.65371280908585
#
# [ Test epoch: 10 ]
#
# Test accuarcy: 72.05
# Test average loss: 0.008208955949544907
# Model Saved!
#
# [ Train epoch: 11 ]
#
# Current batch: 0
# Current benign train accuracy: 0.8203125
# Current benign train loss: 0.5630196928977966
#
# Current batch: 100
# Current benign train accuracy: 0.875
# Current benign train loss: 0.3955114185810089
#
# Current batch: 200
# Current benign train accuracy: 0.8359375
# Current benign train loss: 0.45446619391441345
#
# Current batch: 300
# Current benign train accuracy: 0.859375
# Current benign train loss: 0.47414833307266235
#
# Total benign train accuarcy: 83.968
# Total benign train loss: 180.582673817873
#
# [ Test epoch: 11 ]
#
# Test accuarcy: 79.49
# Test average loss: 0.006040283572673798
# Model Saved!
#
# [ Train epoch: 12 ]
#
# Current batch: 0
# Current benign train accuracy: 0.90625
# Current benign train loss: 0.3218933939933777
#
# Current batch: 100
# Current benign train accuracy: 0.8671875
# Current benign train loss: 0.44217225909233093
#
# Current batch: 200
# Current benign train accuracy: 0.8515625
# Current benign train loss: 0.36991584300994873
#
# Current batch: 300
# Current benign train accuracy: 0.84375
# Current benign train loss: 0.4577186703681946
#
# Total benign train accuarcy: 85.086
# Total benign train loss: 169.59517681598663
#
# [ Test epoch: 12 ]
#
# Test accuarcy: 81.0
# Test average loss: 0.005441815522313118
# Model Saved!
#
# [ Train epoch: 13 ]
#
# Current batch: 0
# Current benign train accuracy: 0.8828125
# Current benign train loss: 0.3574633002281189
#
# Current batch: 100
# Current benign train accuracy: 0.859375
# Current benign train loss: 0.3570318818092346
#
# Current batch: 200
# Current benign train accuracy: 0.875
# Current benign train loss: 0.3803253769874573
#
# Current batch: 300
# Current benign train accuracy: 0.8671875
# Current benign train loss: 0.48265740275382996
#
# Total benign train accuarcy: 85.786
# Total benign train loss: 161.8152937591076
#
# [ Test epoch: 13 ]
#
# Test accuarcy: 77.69
# Test average loss: 0.006581909051537513
# Model Saved!
#
# [ Train epoch: 14 ]
#
# Current batch: 0
# Current benign train accuracy: 0.8359375
# Current benign train loss: 0.3920929431915283
#
# Current batch: 100
# Current benign train accuracy: 0.890625
# Current benign train loss: 0.3116622567176819
#
# Current batch: 200
# Current benign train accuracy: 0.90625
# Current benign train loss: 0.3018679916858673
#
# Current batch: 300
# Current benign train accuracy: 0.828125
# Current benign train loss: 0.4341735243797302
#
# Total benign train accuarcy: 86.63
# Total benign train loss: 151.53789073228836
#
# [ Test epoch: 14 ]
#
# Test accuarcy: 81.68
# Test average loss: 0.00538121367096901
# Model Saved!
#
# [ Train epoch: 15 ]
#
# Current batch: 0
# Current benign train accuracy: 0.8515625
# Current benign train loss: 0.4362005591392517
#
# Current batch: 100
# Current benign train accuracy: 0.875
# Current benign train loss: 0.33480948209762573
#
# Current batch: 200
# Current benign train accuracy: 0.8671875
# Current benign train loss: 0.37008124589920044
#
# Current batch: 300
# Current benign train accuracy: 0.9375
# Current benign train loss: 0.2806030511856079
#
# Total benign train accuarcy: 86.86
# Total benign train loss: 147.44282618165016
#
# [ Test epoch: 15 ]
#
# Test accuarcy: 80.52
# Test average loss: 0.005988742232322693
# Model Saved!
#
# [ Train epoch: 16 ]
#
# Current batch: 0
# Current benign train accuracy: 0.8515625
# Current benign train loss: 0.36005350947380066
#
# Current batch: 100
# Current benign train accuracy: 0.859375
# Current benign train loss: 0.4086339771747589
#
# Current batch: 200
# Current benign train accuracy: 0.90625
# Current benign train loss: 0.39890235662460327
#
# Current batch: 300
# Current benign train accuracy: 0.890625
# Current benign train loss: 0.3684494197368622
#
# Total benign train accuarcy: 87.964
# Total benign train loss: 137.14764013886452
#
# [ Test epoch: 16 ]
#
# Test accuarcy: 85.01
# Test average loss: 0.004462165755033493
# Model Saved!
#
# [ Train epoch: 17 ]
#
# Current batch: 0
# Current benign train accuracy: 0.8984375
# Current benign train loss: 0.34045910835266113
#
# Current batch: 100
# Current benign train accuracy: 0.9296875
# Current benign train loss: 0.17685410380363464
#
# Current batch: 200
# Current benign train accuracy: 0.90625
# Current benign train loss: 0.2940302789211273
#
# Current batch: 300
# Current benign train accuracy: 0.8671875
# Current benign train loss: 0.36194315552711487
#
# Total benign train accuarcy: 88.072
# Total benign train loss: 133.05989807844162
#
# [ Test epoch: 17 ]
#
# Test accuarcy: 82.42
# Test average loss: 0.0050849661618471145
# Model Saved!
#
# [ Train epoch: 18 ]
#
# Current batch: 0
# Current benign train accuracy: 0.90625
# Current benign train loss: 0.26553216576576233
#
# Current batch: 100
# Current benign train accuracy: 0.859375
# Current benign train loss: 0.38488954305648804
#
# Current batch: 200
# Current benign train accuracy: 0.9375
# Current benign train loss: 0.2461761087179184
#
# Current batch: 300
# Current benign train accuracy: 0.8671875
# Current benign train loss: 0.404060959815979
#
# Total benign train accuarcy: 88.562
# Total benign train loss: 129.901689350605
#
# [ Test epoch: 18 ]
#
# Test accuarcy: 86.26
# Test average loss: 0.00426597332060337
# Model Saved!
#
# [ Train epoch: 19 ]
#
# Current batch: 0
# Current benign train accuracy: 0.90625
# Current benign train loss: 0.2628035545349121
#
# Current batch: 100
# Current benign train accuracy: 0.921875
# Current benign train loss: 0.3010757267475128
#
# Current batch: 200
# Current benign train accuracy: 0.859375
# Current benign train loss: 0.35353824496269226
#
# Current batch: 300
# Current benign train accuracy: 0.9296875
# Current benign train loss: 0.3377876579761505
#
# Total benign train accuarcy: 88.928
# Total benign train loss: 126.28088894486427
#
# [ Test epoch: 19 ]
#
# Test accuarcy: 84.02
# Test average loss: 0.004864959594607353
# Model Saved!

# %%
def test_model_on_test_set(model, test_loader):
    model.eval()

    correct = 0
    total = 0

    with torch.no_grad():
        for images, labels in test_loader:
            images = images.to(device)
            labels = labels.to(device)

            outputs = model(images)
            _, predicted = torch.max(outputs, 1)

            total += labels.size(0)
            correct += (predicted == labels).sum().item()

    accuracy = 100 * correct / total
    print(f'Accuracy on test set: {accuracy:.2f}%')

def load_model_with_prefix(model, checkpoint_path):
    checkpoint = torch.load(checkpoint_path)
    model.load_state_dict({k.replace('module.', ''): v for k, v in checkpoint['net'].items()})

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model = ResNet18()
model = model.to(device)

checkpoint_path = './checkpoint/' + file_name
if os.path.exists(checkpoint_path):
    load_model_with_prefix(model, checkpoint_path)
    print('Model weights loaded successfully!')
else:
    print('Model weights not found.')

test_model_on_test_set(model, test_loader)
# Out:
# C:\Users\DenisDrobyshev\AppData\Local\Temp\ipykernel_25400\1069915622.py:22: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   checkpoint = torch.load(checkpoint_path)
# Model weights loaded successfully!
# Accuracy on test set: 84.02%
